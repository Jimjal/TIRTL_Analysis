# %% [markdown]
# # Milestone 模板（轻量版 / .ipynb）
#
# > 只记录：**需求** + **里程碑验收要达到的效果**。
# > Task 拆分、AC 编号、verify 细节由 Antigravity Agent 在执行阶段补全。

# %% [markdown]
# ## 0) 元信息
#
# - Milestone ID: `M-000X`
# - 标题: `<topic>`
# - 版本: `v1`
# - 状态: `Draft / In Progress / Accepted / Rejected`
# - 最后更新: `<YYYY-MM-DD>`
# - 关联 repo / 分支规范: `<可选>`

# %% [markdown]
# ## 1) 背景与目标（Why）
#
# - 背景：
# - 我想解决的问题：
# - 目标（1–3 句话）：

# %% [markdown]
# ## 2) 需求描述（What）
#
# > 用用户视角描述“要做什么”，不要写实现方式。
#
# - 需求 1：
# - 需求 2：
# - 需求 3：

# %% [markdown]
# ## 3) 约束与偏好（Constraints）
#
# - 工具/库/语言偏好：
# - 不能做的事（例如：不改动某些目录/不引入重依赖）：
# - 运行环境（OS/Python 版本/是否需要 conda）：
# - 数据限制（例如：不能提交真实数据到 repo）：

# %% [markdown]
# ## 4) 输入与我能提供的信息（Inputs）
#
# > 列出你能提供的最小信息；不足的在下一节列“待确认”。
#
# - 数据文件：
# - 文件命名/目录结构：
# - 条码表/配置：
# - 示例（header/read片段）：

# %% [markdown]
# ## 5) 预期输出 / 交付物（Deliverables）
#
# > 这是“做完后 repo 里应该有什么”。
#
# - 文档：
# - 脚本/工具：
# - 示例配置/模板：
# - 日志/报告：

# %% [markdown]
# ## 6) 验收要达到的效果（Acceptance Outcomes）
#
# > 不写 AC 编号；只写“验收时应该看到什么”。由 Antigravity 把它们转成可执行/可测的 AC 与 verify。
#
# - 效果 1：
# - 效果 2：
# - 效果 3：

# %% [markdown]
# ## 7) 不做的范围（Non-goals）
#
# -

# %% [markdown]
# ## 8) 待确认 / 风险点（Open Questions / Risks）
#
# - Q1:
# - Q2:
# - Risk:

# %% [markdown]
# ## 9) 变更记录（Change Log）
#
# - v1: 初始需求
